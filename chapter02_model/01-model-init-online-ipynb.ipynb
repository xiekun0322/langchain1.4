# %%
from mimetypes import init
from urllib import response

import langchain_deepseek
import langchain_openai
from langchain_classic.chat_models.base import init_chat_model
from langchain_community.chat_models import ChatZhipuAI
from openai import api_key

# 调用线上大模型

## 1. 调用具体模型产商的API

### 1.1 调用DeepSeek官网的DeepSeek模型

# 调用大模型涉及三个特别重要的参数
# base_url,model_name,api_key

# 举例1：将参数配置在.env配置文件中

# %%
# import os
#
from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek

# 读取.env文件配置中的信息.相关的环境变量以.evn文件中的优先
load_dotenv(override=True)

# DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
# DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

#模型初始化
llm_deepseek = ChatDeepSeek(
    model="deepseek-v4-flash",
    # api_key=DEEPSEEK_API_KEY,
    # api_base=DEEPSEEK_BASE_URL,
)

# 模型调用
response = llm_deepseek.invoke("请用一句话介绍你自己")
print(response)

# %%
# 兼容的写法
# 使用ChatOpenAI
# 举例1：调用deepseek官网的大模型

import os
from langchain_openai import ChatOpenAI

# 加载配置文件
load_dotenv(override=True)

DEEPSEEK_API_KEY=os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL=os.getenv("DEEPSEEK_BASE_URL")

# 获取大模型
model=ChatOpenAI(
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)

print(model.invoke("1 + 1 = ?"))

# %%
# 使用中转平台
# 使用OpenRouter
# 举例1：调用国内大模型

import os
from langchain_openrouter import ChatOpenRouter

# 加载配置文件
load_dotenv(override=True)

OpenRouter_API_KEY=os.getenv("OpenRouter_API_KEY")
OpenRouter_BASE_KEY=os.getenv("OpenRouter_BASE_KEY")

# 获取大模型
model=ChatOpenRouter(
    model="o3-mini",
    api_key=OpenRouter_API_KEY,
    base_url=OpenRouter_BASE_KEY,
)

print(model.invoke("一句话介绍一下你自己"))

# %%
# 使用langchian1.X的统一方式

# 使用 init_chat_model()

# 举例1：调用deepseek官网的deepseek模型

import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

# 加载配置文件
load_dotenv(override=True)

DEEPSEEK_API_KEY=os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL=os.getenv("DEEPSEEK_BASE_URL")

# 获取大模型
model=init_chat_model(
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)

print(model.invoke("一句话介绍一下你自己"))
# Out:
# C:\Users\ZhuanZ\AppData\Roaming\Python\Python314\site-packages\langchain_core\utils\pydantic.py:42: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1 import BaseModel as BaseModelV1
# content='我是DeepSeek，由深度求索公司创造的AI助手，随时乐意帮你解答问题。' additional_kwargs={'refusal': None, 'reasoning_content': '我们 need answer in Chinese. Need one sentence introduce myself. As assistant. Need maybe "我是DeepSeek，由深度求索公司创造的AI助手，乐于为你解答问题。" But user asked 一句话介绍一下你自己. Need comply.'} response_metadata={'token_usage': {'completion_tokens': 69, 'prompt_tokens': 86, 'total_tokens': 155, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 48, 'rejected_prediction_tokens': None, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 86}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': '8a80e221-83f3-4534-8ab4-dc38a82d99c4', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a07a94-9591-7ea2-9a46-f7c30f66ef5f-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 86, 'output_tokens': 69, 'total_tokens': 155, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 48}}

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

# 加载配置文件
load_dotenv(override=True)

DEEPSEEK_API_KEY=os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL=os.getenv("DEEPSEEK_BASE_URL")

# 获取大模型
model=init_chat_model(
    model="deepseek-v4-flash",
    model_provider="openai",
    temperatrue=0.7,    # 温度：越低输出内容越稳定；越高输出内容越随机。默认值：0.7，区间：0~2
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)

print(model.invoke("一句话介绍一下你自己"))

# %%
# max_tokens参数的举例

# 举例：

import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

# 加载配置文件
load_dotenv(override=True)

DEEPSEEK_API_KEY=os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL=os.getenv("DEEPSEEK_BASE_URL")

# 获取大模型
model=init_chat_model(
    model="deepseek-v4-flash",
    model_provider="openai",
    # temperatrue=0.7,    # 温度：越低输出内容越稳定；越高输出内容越随机。默认值：0.7，区间：0~2
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
    max_tokens=10,
)

print(model.invoke("一句话介绍一下你自己"))
